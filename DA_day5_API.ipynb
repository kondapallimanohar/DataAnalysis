# %% [markdown]
# <a href="https://colab.research.google.com/github/kondapallimanohar/DataAnalysis/blob/main/DA_day5_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
page=requests.get("https://randomfox.ca/floof")

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/15.jpg","link":"https:\/\/randomfox.ca\/?i=15"}

# %%
print(page.json())
# Out:
# {'image': 'https://randomfox.ca/images/15.jpg', 'link': 'https://randomfox.ca/?i=15'}

# %% [markdown]
# my api key
#
# 109ab8b6-e649-4823-82a0-9d5182b8f543

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '109ab8b6-e649-4823-82a0-9d5182b8f543',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T09:45:45.434Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 9013, 'name': '1lc1mg83bdu', 'symbol': 'eghrq8vesbw', 'slug': 'tsdfv7z558s', 'cmc_rank': 817, 'num_market_pairs': 7104, 'circulating_supply': 3278, 'total_supply': 6935, 'max_supply': 703, 'infinite_supply': None, 'last_updated': '2024-02-16T09:45:45.433Z', 'date_added': '2024-02-16T09:45:45.433Z', 'tags': ['bxa937a9jtp', 'iiwplecp1cg', 'sylnf5cbox', 'c6jtglqatxv', 'onf6t6fvd5', 'vtit2bb1zks', 'pp4u4gqxus', 'jj9bh1zc2b', '6faji1qhhzg', '522v1yldyzu'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.677486495681203, 'volume_24h': 4348, 'volume_change_24h': 0.8489864000150624, 'percent_change_1h': 0.6547638259826192, 'percent_change_24h': 0.7616032046242092, 'percent_change_7d': 0.18221501063704637, 'market_cap': 0.6475904330541435, 'market_cap_dominance':
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id         name       symbol          slug  cmc_rank  num_market_pairs  \
# 0  9013  1lc1mg83bdu  eghrq8vesbw   tsdfv7z558s       817              7104
# 1  4336  lfblu582f3b  aov7imdfz7c   z38e50w0b7j      2033              8094
# 2  5420  hc5b8em6clf  s4btlauzp2g   v58t14svmbn      9342              4176
# 3  8026  5an52836r75  80hj1vlu3yp   s15voy6aafg      3747              1391
# 4  4074   nv2hfuubh6  xv6sym9ifbb    mo03yvlu08      9286              9616
# 5  3151  e3xdehxbeoi  0l3agullb6a  02mwbuc6zhjx      5443              5860
# 6  7237  2fcibuit11h   x3j75f9dxd   qotdwpik0bm       739              1628
# 7  3727   m16x2ccp4t   nkp8ukizid   d2bxdlnnwwa      5348              2354
# 8  2746  4abt8zwd5vo  fermrerrour   5xxmzfbj2o5      4647              1881
# 9  5771  2oeryhqm9fv  mm0yb71x1yt   ojug5yegjah      2205              4702
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# ...
