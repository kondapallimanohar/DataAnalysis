# %% [markdown]
# <a href="https://colab.research.google.com/github/kondapallimanohar/DataAnalysis/blob/main/DA_day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# accesinb a static website libraries reuired pandas,beautiful soup and libray and importing sub package

# %% [markdown]
# project 1

# %%
#importing libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url="https://www.google.com/search?q=ratpaccheck.in&oq=ratpa&gs_lcrp=EgZjaHJvbWUqBwgCEAAYgAQyBggAEEUYOTIKCAEQABixAxiABDIHCAIQABiABDINCAMQLhjHARjRAxiABDIHCAQQABiABDIGCAUQRRg8MgYIBhBFGDwyBggHEEUYPNIBCDU1NjNqMGo3qAIAsAIA&sourceid=chrome&ie=UTF-8"

# %%
url="https://ratpaccheck.in/"

# %%
req=requests.get(url)

# %%
#access html code
bs=BeautifulSoup(req.text,"html")
print(bs)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://ratpaccheck.in/storage/2022/05/512x512-min.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ratpaccheck.in/storage/2022/05/512x512-min.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://ratpaccheck.in/feed/" rel="alternate" title="RatpacCheck RSS Feed" type="application/rss+xml"/>
# <link href="https://ratpaccheck.in/feed/atom/" rel="alternate" title="RatpacCheck Atom Feed" type="application/atom+xml"/>
# <link href="https://ratpaccheck.in/xmlrpc.php" rel="pingback"/>
# <!--[if lt IE 9]>
# 	<script src="https://ratpaccheck.in/views/e2946d6c7d/js/html5.js"></script>
# 	<![endif]-->
# <title>Home - RatpacCheck</title>
# ...

# %% [markdown]
# extracting a table from html code

# %%
url="https://www.forbesindia.com/article/explainers/top-10-richest-people-india/85909/1"

# %%
req1=requests.get(url)

# %%
soup=BeautifulSoup(req1.text,"html")
print(soup)
# Out:
# <!-- Top header Advertisment --><!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Top 10 Richest People In India In 2024 | Who Is The Richest Man And Woman In India - Forbes India</title>
# <meta content="Gain insights into the extraordinary wealth and remarkable achievements of the ten wealthiest individuals in India, spanning various industries" name="description"/>
# <link href="https://www.forbesindia.com/images/forbesicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.forbesindia.com/media/images/2023/Jun/img_210953_top10.jpg" rel="image_src"/>
# <link href="https://www.forbesindia.com/article/explainers/top-10-richest-people-india/85909/1" rel="canonical"/>
# <link href="https://www.forbesindia.com/amp/article/explainers/top-10-richest-people-india/85909/1" rel="amphtml"/>
# <!-- for Facebook -->
# ...

# %%
table=soup.find('table')
print(table)
# Out:
# <table style="border-collapse: collapse;">
# <tbody>
# <tr>
# <th style="border: 1px solid black; padding: 8px;"><strong>Name &amp; India Rank</strong></th>
# <th style="border: 1px solid black; padding: 8px;"><strong>Global Rank</strong></th>
# <th style="border: 1px solid black; padding: 8px;"><strong>Net worth (US$)</strong></th>
# <th style="border: 1px solid black; padding: 8px;"><strong>Company</strong></th>
# </tr>
# <tr>
# <td style="border: 1px solid black; padding: 8px;">#1 Mukesh Ambani <br/></td>
# <td style="border: 1px solid black; padding: 8px;">11</td>
# <td style="border: 1px solid black; padding: 8px;">$113.0 B</td>
# <td style="border: 1px solid black; padding: 8px;">Reliance Industries</td>
# </tr>
# <tr>
# <td style="border: 1px solid black; padding: 8px;">#2 Gautam Adani <br/></td>
# <td style="border: 1px solid black; padding: 8px;">16<br/></td>
# <td style="border: 1px solid black; padding: 8px;">$81.2 B</td>
# ...

# %%
heading=table.find_all('th')
print(heading)
# Out:
# [<th style="border: 1px solid black; padding: 8px;"><strong>Name &amp; India Rank</strong></th>, <th style="border: 1px solid black; padding: 8px;"><strong>Global Rank</strong></th>, <th style="border: 1px solid black; padding: 8px;"><strong>Net worth (US$)</strong></th>, <th style="border: 1px solid black; padding: 8px;"><strong>Company</strong></th>]

# %%
trs=table.find_all('tr')
print(trs)
# Out:
# [<tr>
# <th style="border: 1px solid black; padding: 8px;"><strong>Name &amp; India Rank</strong></th>
# <th style="border: 1px solid black; padding: 8px;"><strong>Global Rank</strong></th>
# <th style="border: 1px solid black; padding: 8px;"><strong>Net worth (US$)</strong></th>
# <th style="border: 1px solid black; padding: 8px;"><strong>Company</strong></th>
# </tr>, <tr>
# <td style="border: 1px solid black; padding: 8px;">#1 Mukesh Ambani <br/></td>
# <td style="border: 1px solid black; padding: 8px;">11</td>
# <td style="border: 1px solid black; padding: 8px;">$113.0 B</td>
# <td style="border: 1px solid black; padding: 8px;">Reliance Industries</td>
# </tr>, <tr>
# <td style="border: 1px solid black; padding: 8px;">#2 Gautam Adani <br/></td>
# <td style="border: 1px solid black; padding: 8px;">16<br/></td>
# <td style="border: 1px solid black; padding: 8px;">$81.2 B</td>
# <td style="border: 1px solid black; padding: 8px;">Adani Group</td>
# </tr>, <tr>
# ...

# %%
head=[i.text for i in heading]
print(head)
# Out:
# ['Name & India Rank', 'Global Rank', 'Net worth (US$)', 'Company']

# %%
tds=table.find_all('td')
print(tds)
# Out:
# [<td style="border: 1px solid black; padding: 8px;">#1 Mukesh Ambani <br/></td>, <td style="border: 1px solid black; padding: 8px;">11</td>, <td style="border: 1px solid black; padding: 8px;">$113.0 B</td>, <td style="border: 1px solid black; padding: 8px;">Reliance Industries</td>, <td style="border: 1px solid black; padding: 8px;">#2 Gautam Adani <br/></td>, <td style="border: 1px solid black; padding: 8px;">16<br/></td>, <td style="border: 1px solid black; padding: 8px;">$81.2 B</td>, <td style="border: 1px solid black; padding: 8px;">Adani Group</td>, <td style="border: 1px solid black; padding: 8px;">#3 Shiv Nadar <br/></td>, <td style="border: 1px solid black; padding: 8px;">37<br/></td>, <td style="border: 1px solid black; padding: 8px;">$37.1 B</td>, <td style="border: 1px solid black; padding: 8px;">HCL Technologies   <br/></td>, <td style="border: 1px solid black; padding: 8px;">#4 Savitri Jindal &amp; family <br/></td>, <td style="border: 1px solid black; padding: 8px;">58
# ...

# %%
for i in rows[1:9]:
  rd=i.find_all('td')
  eachrow=[i.text for i in rd]
  print(eachrow)
# Out:
# ['#1 Mukesh Ambani ', '11', '$113.0 B', 'Reliance Industries']
# ['#2 Gautam Adani ', '16', '$81.2 B', 'Adani Group']
# ['#3 Shiv Nadar ', '37', '$37.1 B', 'HCL Technologies\xa0\xa0 ']
# ['#4 Savitri Jindal & family ', '58', '$28.9 B', 'JSW Group']
# ['#5 Cyrus Poonawalla ', '68', '$25.6 B', 'Serum Institute of India']
# ['#6 Dilip Shanghvi ', '69', '$25.5 B', 'Sun Pharmaceutical Industries Ltd']
# ['#7 Kumar Birla ', '97', '$18.9 B', 'Aditya Birla Group']
# ['#8 Kushal Pal Singh', '98', '$18.9 B', 'DLF Limited']

# %%
for i in rows[1:9]:
  rd=i.find_all('td')
  eachrow=[j.text for j in rd]
  print(eachrow)
# Out:
# ['#1 Mukesh Ambani ', '11', '$113.0 B', 'Reliance Industries']
# ['#2 Gautam Adani ', '16', '$81.2 B', 'Adani Group']
# ['#3 Shiv Nadar ', '37', '$37.1 B', 'HCL Technologies\xa0\xa0 ']
# ['#4 Savitri Jindal & family ', '58', '$28.9 B', 'JSW Group']
# ['#5 Cyrus Poonawalla ', '68', '$25.6 B', 'Serum Institute of India']
# ['#6 Dilip Shanghvi ', '69', '$25.5 B', 'Sun Pharmaceutical Industries Ltd']
# ['#7 Kumar Birla ', '97', '$18.9 B', 'Aditya Birla Group']
# ['#8 Kushal Pal Singh', '98', '$18.9 B', 'DLF Limited']

# %%
mydata=pd.DataFrame(columns=head)
print(mydata)
# Out:
# Empty DataFrame
# Columns: [Name & India Rank, Global Rank, Net worth (US$), Company]
# Index: []

# %%
import pandas as pd
import seaborn as sns

# %%
mydata=pd.DataFrame(columns=head)
a=0
for i in rows[1:9]:
  rd=i.find_all('td')
  eachrow=[j.text for j in rd]
  head=[i.text for i in heading]
  mydata.loc[a]=eachrow
  a=a+1
mydata
# Out:
#              Name & India Rank Global Rank Net worth (US$)  \
# 0            #1 Mukesh Ambani           11        $113.0 B
# 1             #2 Gautam Adani           16         $81.2 B
# 2               #3 Shiv Nadar           37         $37.1 B
# 3  #4 Savitri Jindal & family           58         $28.9 B
# 4         #5 Cyrus Poonawalla           68         $25.6 B
# 5           #6 Dilip Shanghvi           69         $25.5 B
# 6              #7 Kumar Birla           97         $18.9 B
# 7          #8 Kushal Pal Singh          98         $18.9 B
#
#                              Company
# 0                Reliance Industries
# 1                        Adani Group
# 2                HCL Technologies
# 3                          JSW Group
# 4           Serum Institute of India
# 5  Sun Pharmaceutical Industries Ltd
# 6                 Aditya Birla Group
# 7                        DLF Limited

# %%
mydata.to_csv("richmen.csv")

# %%
pip install selenium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.2/460.2 kB 36.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.0 MB/s eta 0:00:00
# ...

# %%
pip install webdriver_manager

# %%
import selenium

# %%
import webdriver_manager

# %%
import pandas as pd

# %%
from selenium import webdriver
from time import sleep
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
#define options and set capabilities
options=webdriver.ChromeOptions()
options.add_argument('--some-options')

# %%
#create webdriver instance with options
driver =webdriver.Chrome(options=options)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-20-a25a9b59d717> in <cell line: 2>()
#       1 #create webdriver instance with options
# ----> 2 driver =webdriver.Chrome(options=options)
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      59
#      60         try:
# ---> 61             super().__init__(command_executor=executor, options=options)
#      62         except Exception:
# ...
